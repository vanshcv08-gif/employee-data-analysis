# %%
import pandas as pd

# %%
df=pd.read_csv(r"C:\Users\Admin\Downloads\customer_data.csv")

# %%
df
# Out:
#      id   customer_name  age  gender region occupation  purchase_amount  \
# 0     1  Alice Thompson   25  Female  North   Engineer           150.75
# 1     2      Robert Lee   32    Male  South    Teacher            89.50
# 2     3      Emily Chen   28  Female   West   Designer           220.30
# 3     4   Michael Patel   45    Male   East    Manager           175.20
# 4     5   Sophia Nguyen   19  Female  North    Student            65.10
# ..  ...             ...  ...     ...    ...        ...              ...
# 95   96   Aliyah Holmes   29  Female  North    Analyst           145.60
# 96   97   Declan Porter   42    Male  South   Engineer           195.25
# 97   98    Sienna Riley   26  Female   West    Student            85.30
# 98   99   Asher Wallace   34    Male   East    Teacher           160.75
# 99  100     Clara Dixon   28  Female  North     Artist            90.40
#
#    loyalty_program preferred_category delivery_preference
# ...

# %%
#question 1
df.loc[df['id'] == 15, :]
# Out:
#     id   customer_name  age  gender region occupation  purchase_amount  \
# 14  15  Charlotte Hall   26  Female   West   Designer           130.85
#
#    loyalty_program preferred_category delivery_preference
# 14             Yes         Home Decor             Express

# %%
#quetion2
df.iloc[0:11,0:4]
# Out:
#     id   customer_name  age  gender
# 0    1  Alice Thompson   25  Female
# 1    2      Robert Lee   32    Male
# 2    3      Emily Chen   28  Female
# 3    4   Michael Patel   45    Male
# 4    5   Sophia Nguyen   19  Female
# 5    6    James Wilson   37    Male
# 6    7    Olivia Brown   29  Female
# 7    8  William Garcia   52    Male
# 8    9    Ava Martinez   23  Female
# 9   10      Liam Davis   41    Male
# 10  11  Isabella Clark   30  Female

# %%
#quetion 3
df.loc[df['region']== 'North', ['customer_name','purchase_amount']]
# Out:
#       customer_name  purchase_amount
# 0    Alice Thompson           150.75
# 4     Sophia Nguyen            65.10
# 8      Ava Martinez            95.25
# 12        Mia Lewis           110.15
# 16     Amelia Allen            70.20
# 20     Evelyn Adams            85.30
# 24   Emily Mitchell           135.60
# 28   Sofia Phillips           115.30
# 32  Madison Edwards            90.50
# 36        Zoey Reed           130.95
# 40     Riley Brooks            80.15
# 44       Hannah Cox           125.80
# 48   Natalie Fisher            95.40
# 52       Hazel West           140.15
# 55     Aubrey Myers           130.80
# 59    Arianna Price           145.15
# 63   Aurora Jenkins            90.80
# 67      Clara Wells           140.65
# 71      Maya Hunter           135.40
# 75       Lydia Cole            90.25
# 79    Aria Peterson            85.15
# 83  Addison Simmons           130.70
# 87      Autumn Ford           125.20
# 91       Audrey Fox           135.85
# ...

# %%
#question number4
df.iloc[85:,3:6]
# Out:
#     gender region  occupation
# 85  Female   West      Artist
# 86    Male   East    Engineer
# 87  Female  North     Teacher
# 88    Male  South      Doctor
# 89  Female   West     Student
# 90    Male   East  Consultant
# 91  Female  North   Marketing
# 92    Male  South     Manager
# 93  Female   West    Designer
# 94    Male   East      Lawyer
# 95  Female  North     Analyst
# 96    Male  South    Engineer
# 97  Female   West     Student
# 98    Male   East     Teacher
# 99  Female  North      Artist

# %%
#question no.4
df.iloc[-15:,[3,6]]
# Out:
#     gender  purchase_amount
# 85  Female            95.50
# 86    Male           190.65
# 87  Female           125.20
# 88    Male           285.75
# 89  Female            80.90
# 90    Male           210.30
# 91  Female           135.85
# 92    Male           245.40
# 93  Female           130.95
# 94    Male           170.50
# 95  Female           145.60
# 96    Male           195.25
# 97  Female            85.30
# 98    Male           160.75
# 99  Female            90.40

# %%
x = df.tail(15)
x.iloc[:,3:6]
# Out:
#     gender region  occupation
# 85  Female   West      Artist
# 86    Male   East    Engineer
# 87  Female  North     Teacher
# 88    Male  South      Doctor
# 89  Female   West     Student
# 90    Male   East  Consultant
# 91  Female  North   Marketing
# 92    Male  South     Manager
# 93  Female   West    Designer
# 94    Male   East      Lawyer
# 95  Female  North     Analyst
# 96    Male  South    Engineer
# 97  Female   West     Student
# 98    Male   East     Teacher
# 99  Female  North      Artist

# %%
#question5. Select all columns for customers with purchase_amount greater than 200.
df.loc[df["purchase_amount"]>200,:]
# Out:
#     id       customer_name  age  gender region  occupation  purchase_amount  \
# 2    3          Emily Chen   28  Female   West    Designer           220.30
# 5    6        James Wilson   37    Male  South      Doctor           300.80
# 7    8      William Garcia   52    Male   East  Consultant           200.60
# 13  14        Ethan Walker   38    Male  South     Manager           250.40
# 15  16     Alexander Young   49    Male   East      Doctor           280.95
# 19  20         Henry Green   44    Male   East  Consultant           210.25
# 25  26      Benjamin Perez   46    Male  South     Manager           230.75
# 29  30     Elijah Campbell   40    Male  South      Doctor           270.85
# 31  32         Logan Evans   43    Male   East  Consultant           205.65
# 35  36       Samuel Morris   48    Male   East     Manager           240.80
# 39  40         Joseph Bell   41    Male   East      Doctor           275.20
# ...

# %%
#question6. Select every third row from the first 30 rows and columns 0, 2, and 5.
df.iloc[:30:3,[0,2,5]]
# Out:
#     id  age occupation
# 0    1   25   Engineer
# 3    4   45    Manager
# 6    7   29    Analyst
# 9   10   41     Lawyer
# 12  13   34    Teacher
# 15  16   49     Doctor
# 18  19   28   Engineer
# 21  22   36     Lawyer
# 24  25   27   Designer
# 27  28   35   Engineer

# %%
#question7. Select 'customer_name', 'age', and 'occupation' for customers with gender 'Female'.
df.loc[df["gender"]=="Female",["customer_name","age","occupation","gender"]]
# Out:
#        customer_name  age occupation  gender
# 0     Alice Thompson   25   Engineer  Female
# 2         Emily Chen   28   Designer  Female
# 4      Sophia Nguyen   19    Student  Female
# 6       Olivia Brown   29    Analyst  Female
# 8       Ava Martinez   23     Artist  Female
# 10    Isabella Clark   30  Marketing  Female
# 12         Mia Lewis   34    Teacher  Female
# 14    Charlotte Hall   26   Designer  Female
# 16      Amelia Allen   21    Student  Female
# 18      Harper Scott   28   Engineer  Female
# 20      Evelyn Adams   24     Artist  Female
# 22    Abigail Nelson   31  Marketing  Female
# 24    Emily Mitchell   27   Designer  Female
# 26     Avery Roberts   22    Student  Female
# 28    Sofia Phillips   29    Analyst  Female
# 30      Grace Parker   26  Marketing  Female
# 32   Madison Edwards   23     Artist  Female
# 34     Layla Stewart   30    Teacher  Female
# 36         Zoey Reed   25   Designer  Female
# 38   Penelope Morgan   28    Analyst  Female
# ...

# %%
#question8. Select the 20th to 25th rows (inclusive) and the last 4 columns.
df.iloc[20:25,-5:]
# Out:
#    occupation  purchase_amount loyalty_program preferred_category  \
# 20     Artist            85.30             Yes              Books
# 21     Lawyer           170.80              No           Clothing
# 22  Marketing           125.90             Yes         Home Decor
# 23    Teacher           155.45              No        Electronics
# 24   Designer           135.60             Yes              Books
#
#    delivery_preference
# 20             Express
# 21            Standard
# 22             Express
# 23            Standard
# 24             Express

# %%
#9. Select all columns for customers enrolled in the loyalty program (loyalty_program = 'Yes').

df.loc[df["loyalty_program"]=='Yes',:]
# Out:
#      id     customer_name  age  gender region occupation  purchase_amount  \
# 0     1    Alice Thompson   25  Female  North   Engineer           150.75
# 2     3        Emily Chen   28  Female   West   Designer           220.30
# 4     5     Sophia Nguyen   19  Female  North    Student            65.10
# 6     7      Olivia Brown   29  Female   West    Analyst           120.45
# 8     9      Ava Martinez   23  Female  North     Artist            95.25
# 10   11    Isabella Clark   30  Female   West  Marketing           140.70
# 12   13         Mia Lewis   34  Female  North    Teacher           110.15
# 14   15    Charlotte Hall   26  Female   West   Designer           130.85
# 16   17      Amelia Allen   21  Female  North    Student            70.20
# 18   19      Harper Scott   28  Female   West   Engineer           190.50
# 20   21      Evelyn Adams   24  Female  North     Artist            85.30
# 22   23    Abigail Nelson   31  Female   West  Marketing           125.90
# ...

# %%
#question10. Select the first 5 columns for rows 10 to 20.
df.iloc[10:20,0:5]
# Out:
#     id    customer_name  age  gender region
# 10  11   Isabella Clark   30  Female   West
# 11  12   Noah Rodriguez   27    Male   East
# 12  13        Mia Lewis   34  Female  North
# 13  14     Ethan Walker   38    Male  South
# 14  15   Charlotte Hall   26  Female   West
# 15  16  Alexander Young   49    Male   East
# 16  17     Amelia Allen   21  Female  North
# 17  18      Daniel King   33    Male  South
# 18  19     Harper Scott   28  Female   West
# 19  20      Henry Green   44    Male   East

# %%
# question11;-Select 'customer_name' and 'preferred_category' for customers with purchase_amount above 150.
df.loc[df["purchase_amount"]>150,["customer_name","preferred_category","purchase_amount"]]
# Out:
#          customer_name preferred_category  purchase_amount
# 0       Alice Thompson        Electronics           150.75
# 2           Emily Chen         Home Decor           220.30
# 3        Michael Patel        Electronics           175.20
# 5         James Wilson           Clothing           300.80
# 7       William Garcia        Electronics           200.60
# 9           Liam Davis           Clothing           180.90
# 11      Noah Rodriguez        Electronics           160.35
# 13        Ethan Walker           Clothing           250.40
# 15     Alexander Young        Electronics           280.95
# 18        Harper Scott        Electronics           190.50
# 19         Henry Green         Home Decor           210.25
# 21         Lucas Baker           Clothing           170.80
# 23         Jack Carter        Electronics           155.45
# 25      Benjamin Perez           Clothing           230.75
# 27        Mason Turner        Electronics           195.20
# ...

# %%
#question12. Select rows 40 to 50 and columns 'customer_name', 'gender', and 'delivery_preference' by their index positions.
df.iloc[40:50,[1,3,9]]
# Out:
#      customer_name  gender delivery_preference
# 40    Riley Brooks  Female             Express
# 41   Carter Cooper    Male            Standard
# 42     Aria Bailey  Female             Express
# 43     Owen Rivera    Male            Standard
# 44      Hannah Cox  Female             Express
# 45       Luke Ward    Male            Standard
# 46   Stella Butler  Female             Express
# 47      Isaac Wood    Male            Standard
# 48  Natalie Fisher  Female             Express
# 49   Grayson Stone    Male            Standard

# %%
df.columns
# Out:
# Index(['id', 'customer_name', 'age', 'gender', 'region', 'occupation',
#        'purchase_amount', 'loyalty_program', 'preferred_category',
#        'delivery_preference'],
#       dtype='object')

# %%
#question13. Select all columns for customers aged 25 who prefer 'Books' as their category.
df.loc[(df["preferred_category"]=="Books") & (df["age"]==25)]
# Out:
#     id customer_name  age  gender region occupation  purchase_amount  \
# 36  37     Zoey Reed   25  Female  North   Designer           130.95
#
#    loyalty_program preferred_category delivery_preference
# 36             Yes              Books             Express

# %%
#quesrtion14. Select the 6th column for the first 30 rows.
df.iloc[:30,6]
# Out:
# 0     150.75
# 1      89.50
# 2     220.30
# 3     175.20
# 4      65.10
# 5     300.80
# 6     120.45
# 7     200.60
# 8      95.25
# 9     180.90
# 10    140.70
# 11    160.35
# 12    110.15
# 13    250.40
# 14    130.85
# 15    280.95
# 16     70.20
# 17    145.65
# 18    190.50
# 19    210.25
# 20     85.30
# 21    170.80
# 22    125.90
# 23    155.45
# 24    135.60
# 25    230.75
# 26     75.15
# 27    195.20
# 28    115.30
# 29    270.85
# Name: purchase_amount, dtype: float64

# %%
df
# Out:
#      id   customer_name  age  gender region occupation  purchase_amount  \
# 0     1  Alice Thompson   25  Female  North   Engineer           150.75
# 1     2      Robert Lee   32    Male  South    Teacher            89.50
# 2     3      Emily Chen   28  Female   West   Designer           220.30
# 3     4   Michael Patel   45    Male   East    Manager           175.20
# 4     5   Sophia Nguyen   19  Female  North    Student            65.10
# ..  ...             ...  ...     ...    ...        ...              ...
# 95   96   Aliyah Holmes   29  Female  North    Analyst           145.60
# 96   97   Declan Porter   42    Male  South   Engineer           195.25
# 97   98    Sienna Riley   26  Female   West    Student            85.30
# 98   99   Asher Wallace   34    Male   East    Teacher           160.75
# 99  100     Clara Dixon   28  Female  North     Artist            90.40
#
#    loyalty_program preferred_category delivery_preference
# ...

# %%
#15. Select 'customer_name', 'purchase_amount', and 'region' for customers with delivery_preference 'Express'.
df.loc[df["delivery_preference"]=="Express",["customer_name", "purchase_amount","region","delivery_preference"]]
# Out:
#        customer_name  purchase_amount region delivery_preference
# 0     Alice Thompson           150.75  North             Express
# 2         Emily Chen           220.30   West             Express
# 4      Sophia Nguyen            65.10  North             Express
# 6       Olivia Brown           120.45   West             Express
# 8       Ava Martinez            95.25  North             Express
# 10    Isabella Clark           140.70   West             Express
# 12         Mia Lewis           110.15  North             Express
# 14    Charlotte Hall           130.85   West             Express
# 16      Amelia Allen            70.20  North             Express
# 18      Harper Scott           190.50   West             Express
# 20      Evelyn Adams            85.30  North             Express
# 22    Abigail Nelson           125.90   West             Express
# 24    Emily Mitchell           135.60  North             Express
# ...

# %%
#16. Select rows 5, 15, 25, 35, and 45 and columns 1, 4, and 7.
df.iloc[[5,15,25,35,45],[1,4,7]]
# Out:
#       customer_name region loyalty_program
# 5      James Wilson  South              No
# 15  Alexander Young   East              No
# 25   Benjamin Perez  South              No
# 35    Samuel Morris   East              No
# 45        Luke Ward  South              No

# %%
#question17. Select all columns for customers whose names start with 'S'.
df.loc[df["customer_name"].str.startswith("S")]
# Out:
#     id     customer_name  age  gender region occupation  purchase_amount  \
# 4    5     Sophia Nguyen   19  Female  North    Student            65.10
# 28  29    Sofia Phillips   29  Female  North    Analyst           115.30
# 35  36     Samuel Morris   48    Male   East    Manager           240.80
# 46  47     Stella Butler   31  Female   West   Engineer           190.90
# 61  62  Savannah Sanders   29  Female   West  Marketing           135.30
# 65  66      Skylar Ortiz   27  Female   West   Designer           125.95
# 97  98      Sienna Riley   26  Female   West    Student            85.30
#
#    loyalty_program preferred_category delivery_preference
# 4              Yes              Books             Express
# 28             Yes              Books             Express
# 35              No        Electronics            Standard
# 46             Yes        Electronics             Express
# 61             Yes         Home Decor             Express
# ...

# %%
#18 Select the last 8 rows and the first 3 columns.
df.iloc[-8:,0:3]
# Out:
#      id  customer_name  age
# 92   93  Caleb Gardner   45
# 93   94    Piper Ellis   25
# 94   95    Kayden Boyd   37
# 95   96  Aliyah Holmes   29
# 96   97  Declan Porter   42
# 97   98   Sienna Riley   26
# 98   99  Asher Wallace   34
# 99  100    Clara Dixon   28

# %%
#19. Select 'customer_name' and 'purchase_amount' for customers with purchase_amount between 100 and 200 (inclusive).
df.loc[(df["purchase_amount"].between(100,200)][["customer_name","purchase_amount"]]
# Out:
#        customer_name  purchase_amount
# 0     Alice Thompson           150.75
# 3      Michael Patel           175.20
# 6       Olivia Brown           120.45
# 9         Liam Davis           180.90
# 10    Isabella Clark           140.70
# 11    Noah Rodriguez           160.35
# 12         Mia Lewis           110.15
# 14    Charlotte Hall           130.85
# 17       Daniel King           145.65
# 18      Harper Scott           190.50
# 21       Lucas Baker           170.80
# 22    Abigail Nelson           125.90
# 23       Jack Carter           155.45
# 24    Emily Mitchell           135.60
# 27      Mason Turner           195.20
# 28    Sofia Phillips           115.30
# 30      Grace Parker           140.40
# 33     Aiden Collins           165.25
# 34     Layla Stewart           120.70
# 36         Zoey Reed           130.95
# 37        David Cook           185.10
# 38   Penelope Morgan           145.35
# 42       Aria Bailey           135.65
# 43       Owen Rivera           160.30
# ...

# %%
#question20. Select every 4th row from 0 to 60 and columns 3, 6, and 9.
df.iloc[:60:4,[3,6,9]]
# Out:
#     gender  purchase_amount delivery_preference
# 0   Female           150.75             Express
# 4   Female            65.10             Express
# 8   Female            95.25             Express
# 12  Female           110.15             Express
# 16  Female            70.20             Express
# 20  Female            85.30             Express
# 24  Female           135.60             Express
# 28  Female           115.30             Express
# 32  Female            90.50             Express
# 36  Female           130.95             Express
# 40  Female            80.15             Express
# 44  Female           125.80             Express
# 48  Female            95.40             Express
# 52  Female           140.15             Express
# 56    Male           215.45            Standard

# %%
#21. Select 'customer_name', 'occupation', and 'loyalty_program' for customers aged between 20 and 30 (inclusive).
df.loc[df["age"].between(20,30)][["customer_name","occupation","loyalty_program","age"]]
# Out:
#        customer_name occupation loyalty_program  age
# 0     Alice Thompson   Engineer             Yes   25
# 2         Emily Chen   Designer             Yes   28
# 6       Olivia Brown    Analyst             Yes   29
# 8       Ava Martinez     Artist             Yes   23
# 10    Isabella Clark  Marketing             Yes   30
# 11    Noah Rodriguez   Engineer              No   27
# 14    Charlotte Hall   Designer             Yes   26
# 16      Amelia Allen    Student             Yes   21
# 18      Harper Scott   Engineer             Yes   28
# 20      Evelyn Adams     Artist             Yes   24
# 24    Emily Mitchell   Designer             Yes   27
# 26     Avery Roberts    Student             Yes   22
# 28    Sofia Phillips    Analyst             Yes   29
# 30      Grace Parker  Marketing             Yes   26
# 32   Madison Edwards     Artist             Yes   23
# 34     Layla Stewart    Teacher             Yes   30
# 36         Zoey Reed   Designer             Yes   25
# ...

# %%
#22. Select rows 60 to 70 and the columns corresponding to 'age', 'region', and 'preferred_category'.
df.loc[60:70,["age","region","preferred_category"]]
# Out:
#     age region preferred_category
# 60   41  South        Electronics
# 61   29   West         Home Decor
# 62   36   East           Clothing
# 63   24  North              Books
# 64   48  South        Electronics
# 65   27   West         Home Decor
# 66   35   East           Clothing
# 67   30  North              Books
# 68   42  South        Electronics
# 69   25   West         Home Decor
# 70   39   East           Clothing

# %%
#23. Select all columns for customers in the East region with purchase_amount less than 150.
df.loc[(df["purchase_amount"]<150) & (df["region"]=="East")]
# Out:
# Empty DataFrame
# Columns: [id, customer_name, age, gender, region, occupation, purchase_amount, loyalty_program, preferred_category, delivery_preference]
# Index: []

# %%
#question24. Select the first 12 rows and the last 3 columns.
df.iloc[:12,[-1,-2,-3]]
# Out:
#    delivery_preference preferred_category loyalty_program
# 0              Express        Electronics             Yes
# 1             Standard           Clothing              No
# 2              Express         Home Decor             Yes
# 3             Standard        Electronics              No
# 4              Express              Books             Yes
# 5             Standard           Clothing              No
# 6              Express         Home Decor             Yes
# 7             Standard        Electronics              No
# 8              Express              Books             Yes
# 9             Standard           Clothing              No
# 10             Express         Home Decor             Yes
# 11            Standard        Electronics              No

# %%
#25. Select 'customer_name', 'age', and 'delivery_preference' for customers with id in the range 30 to 50.
df.loc[30:50,["customer_name","age","delivery_preference"]]
# Out:
#       customer_name  age delivery_preference
# 30     Grace Parker   26             Express
# 31      Logan Evans   43            Standard
# 32  Madison Edwards   23             Express
# 33    Aiden Collins   37            Standard
# 34    Layla Stewart   30             Express
# 35    Samuel Morris   48            Standard
# 36        Zoey Reed   25             Express
# 37       David Cook   34            Standard
# 38  Penelope Morgan   28             Express
# 39      Joseph Bell   41            Standard
# 40     Riley Brooks   24             Express
# 41    Carter Cooper   39            Standard
# 42      Aria Bailey   27             Express
# 43      Owen Rivera   45            Standard
# 44       Hannah Cox   29             Express
# 45        Luke Ward   36            Standard
# 46    Stella Butler   31             Express
# 47       Isaac Wood   42            Standard
# 48   Natalie Fisher   26             Express
# 49    Grayson Stone   38            Standard
# ...
